# %% [markdown]
# # LLM Selection Criteria
#
# - In this tutorial we will answer folowing two questions:
#   1. How to select LLMs related to your business case?
#   2. How to compare and choose one finalized LLM for your Business case?
